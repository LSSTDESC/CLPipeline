# %%
from firecrown.models.cluster.abundance import ClusterAbundance
from firecrown.models.cluster.deltasigma import ClusterDeltaSigma
import pyccl as ccl
import numpy as np
from firecrown.models.cluster.recipes.murata_binned_spec_z_deltasigma import MurataBinnedSpecZDeltaSigmaRecipe as MDS
import sacc
from firecrown.modeling_tools import ModelingTools
from firecrown.models.cluster.properties import ClusterProperty
from firecrown.likelihood.binned_cluster_number_counts_deltasigma import BinnedClusterDeltaSigma

# %% [markdown]
# # Firecrown Tutorial
#
# ## 1. Introduction
# Firecrown is a framework to run likelihoods. It connects theory predictions to `cosmosis`, a sampler framework, enabling MCMC runs.
#
# There are several likelihood options built into Firecrown. Generally, we just need to provide:
# - A likelihood Python function
# - Some configuration files
#
# In this tutorial, we will focus on:
# - How to run the cluster examples
# - How the prediction module works
# - How to structure a Python likelihood for Firecrown
# - How to obtain the theory prediction in a Python file

# %% [markdown]
# ## 2. How to run and which files are needed
# To run Firecrown, we need **three different files**:
#
# 1. **Likelihood file** (e.g. `cluster_redshift_richness_deltasigma.py`)
# 2. **Cosmosis configuration file** (e.g. [cluster_counts_mean_mass_redshift_richness_shear.ini](https://github.com/LSSTDESC/firecrown/blob/master/examples/cluster_number_counts/cluster_counts_mean_mass_redshift_richness_shear.ini))
# 3. **Cosmosis parameters file** – defines cosmological and sampling parameters (e.g. [cluster_richness_values_deltasigma.ini](https://github.com/LSSTDESC/firecrown/blob/master/examples/cluster_number_counts/cluster_richness_values_deltasigma.ini))

# %% [markdown]
# ## 3. Likelihood file
# The likelihood file must define the method `build_likelihood`, which returns a Firecrown likelihood and modeling tools.
#
# For example, in `cluster_redshift_richness_deltasigma.py`:
#
# ```
# def build_likelihood(
#     build_parameters: NamedParameters,
# ) -> tuple[Likelihood, ModelingTools]:
#     """Builds the likelihood for Firecrown."""
#     # Pull params for the likelihood from build_parameters
#     average_on = ClusterProperty.NONE
#     if build_parameters.get_bool("use_cluster_counts", True):
#         average_on |= ClusterProperty.COUNTS
#     if build_parameters.get_bool("use_mean_log_mass", True):
#         average_on |= ClusterProperty.MASS
#     if build_parameters.get_bool("use_mean_deltasigma", True):
#         average_on |= ClusterProperty.DELTASIGMA
#
#     survey_name = "numcosmo_simulated_redshift_richness_deltasigma"
#     likelihood = ConstGaussian(
#         [
#             BinnedClusterNumberCounts(
#                 average_on, survey_name, MurataBinnedSpecZRecipe()
#             ),
#             BinnedClusterDeltaSigma(
#                 average_on, survey_name, MurataBinnedSpecZDeltaSigmaRecipe()
#             ),
#         ]
#     )
#
#     # Read in sacc data
#     sacc_file_nm = "cluster_redshift_richness_deltasigma_sacc_data.fits"
#     sacc_path = os.path.expanduser(
#         os.path.expandvars("${FIRECROWN_DIR}/examples/cluster_number_counts/")
#     )
#     sacc_data = sacc.Sacc.load_fits(os.path.join(sacc_path, sacc_file_nm))
#     likelihood.read(sacc_data)
#
#     cluster_abundance = get_cluster_abundance()
#     cluster_deltasigma = get_cluster_deltasigma()
#
#     modeling_tools = ModelingTools(
#         cluster_abundance=cluster_abundance, cluster_deltasigma=cluster_deltasigma
#     )
#
#     return likelihood, modeling_tools
# ```
#
# Key points:
# - The likelihood must **read the data** from a SACC file.
# - Firecrown provides helpers to interpret the data.
# - The likelihood must also include **statistics that compute the theoretical prediction** (e.g. `BinnedClusterNumberCounts`, `BinnedClusterDeltaSigma`).

# %% [markdown]
# ## 4. Cosmosis Configuration Files
#
# In the Cosmosis files, we define the sampler to be used, the configurations for the sampler, and which likelihood file we will use. It is basically to set all the paths and recommended files in place. Let us look at `examples/cluster_number_counts/cluster_counts_mean_mass_redshift_richness_shear.ini`:
#
#
#
# ```
# [runtime]
# sampler = test
# resume = T
# root = ${PWD}
# ```
#
# The test sampler runs just one iteration. It is useful to see if everything is set correctly. When running an MCMC, one must change the sampler option.
#
# In the pipeline section, we set the path to the parameters file, in this case `cluster_richness_values_deltasigma.ini`, and the modules we want to use:
#
# ```
# [pipeline]
# modules = consistency camb firecrown_likelihood
# values = cluster_richness_values_deltasigma.ini
# likelihoods = firecrown
# quiet = T
# debug = T
# timing = T
# ```
#
# Finally, in the Firecrown likelihood section, we set parameters that will be used in our likelihood file above. You can see that these parameters were accessed with `build_parameters` in the likelihood file. The `sampling_parameters_sections` are defined in the parameters file cited above. The cosmological parameters are already expected by the file, so if your statistics have some unique parameters to be varied, you have to specify them in a new section and include this section here.
#
#
# ```
# [firecrown_likelihood]
# ;; Fix this to use an environment variable to find the files.
# ;; Set FIRECROWN_DIR to the base of the firecrown installation (or build, if you haven't
# ;; installed it)
# file = /global/cfs/projectdirs/lsst/groups/CL/cl_pipeline_project/conda_envs/firecrown_clp/lib/python3.13/site-packages/firecrown/connector/cosmosis/likelihood.py
# likelihood_source = cluster_redshift_richness_deltasigma.py
# sampling_parameters_sections = firecrown_number_counts
# use_cluster_counts = True
# use_mean_log_mass = False
# use_mean_deltasigma = True
# ```
#
# ```
# [test]
# fatal_errors = T
# save_dir = output_counts_mean_mass
#
# [metropolis]
# samples = 1000
# nsteps = 1
# ```

# %% [markdown]
# ## 5. The parameters configuration file
# In the parameter configuration file is where we set our cosmological parameters plus the parameters that need to be varied in our code. Let us take a look at `cluster_richness_values_deltasigma.ini`
#
# ```
# ; Parameters and data in CosmoSIS are organized into sections
# ; so we can easily see what they mean.
# ; There is only one section in this case, called cosmological_parameters
# [cosmological_parameters]
#
# ; These are the only cosmological parameters being varied.
# omega_c = 0.1552 0.22 0.3552
# # We are choosing to use a flat prior in sigma_8.
# # To choose a float prior in A_s, remove the specification
# # of a prior for sigma_8 and replace it with the
# # desired range for A_s
# sigma_8 = 0.7 0.800 0.9
# ; The following parameters are set, but not varied.
# ;
# omega_k = 0.0
# omega_b = 0.0448
# tau = 0.08
# n_s = 0.963
# h0 = 0.71
# w = -1.0
# wa = 0.0
#
# [firecrown_number_counts]
# ; These are the firecrown likelihood parameters.
# ; These parameters are used to set the richness-mass
# ; proxy relation using the data from cluster number counts.
# ;
# ; The following parameters can be fixed in the same way as the above
# ; cosmological parameters if needed.
# mu_p0 = 3.19
# mu_p1 = 0.868
# mu_p2 = -0.3
# sigma_p0 = 0.33
# sigma_p1 = -0.034
# sigma_p2 = 0.0
# cluster_conc = 4.
# ```
#
# The cosmological parameters section is always present, while for this specific example, we define also the firecrown number counts section with the parameters we want to vary or set in our statiscs. A single value means that this will be the parameter set for this parameter. 3 values mean that the value will be varied between the left and right and start in the midle, with flat priors.

# %% [markdown]
# ## 6. Running Firecrown clusters
#
# Once all files are set, run in the terminal:
#
# ```bash
# cosmosis cluster_counts_mean_mass_redshift_richness_shear.ini
# ```
#
# ⚠️ Use this only with the **test sampler**.
# For MCMC chains, submit as a **slurm job**.
#
# After running:
#
# ```bash
# cosmosis-postprocess -o output/cluster_number_counts.txt --burn 0.3
# ```
#
# This generates plots and statistics using the `cosmosis-postprocess` package.

# %% [markdown]
# ## 7. Cluster modeling in Firecrown
# Now we will discuss a bit of the modeling theoretical prediction code that is present in firecrown. So the modeling code consists on some files:
#
# - `abundance.py` → cluster abundance object
# - `deltasigma.py` → tangential shear predictions
#
# These two files define the cluster abundance object and the predictions for the shear and cluster abundance below we will see how it works. Note that: the mass information for clusters are in log10. To update the cosmology we have to use the update ingredients that comes from the updatable object
#
# Another files I will not get into detail are:
# - `cluster_data.py`, `deltasigma_data.py`, `abundance_data.py` → data handling (especially SACC files)
# - `kernel.py` → selection functions (completeness, purity)
# - `mass_proxy.py` → mass proxy
#
# Let us see the cluster objects.

# %%
hmf = ccl.halos.MassFuncDespali16()
min_mass, max_mass = 13., 16.
min_z, max_z = 0.2, 0.8
cluster_deltasigma = ClusterDeltaSigma((min_mass, max_mass), (min_z, max_z), hmf)
cluster_abundance = ClusterAbundance((min_mass, max_mass), (min_z, max_z), hmf)
cosmo_ccl = ccl.Cosmology(
Omega_c=0.2052,
Omega_b=0.0448,
h=0.71,
n_s=0.963,
sigma8=0.8,
Omega_k=0.0,
Neff=3.044,
m_nu=0.0,
w0=-1.0,
wa=0.0,
T_CMB=2.7255
)
cluster_abundance.update_ingredients(cosmo_ccl)
cluster_deltasigma.update_ingredients(cosmo_ccl)
print(cluster_abundance.mass_function(mass=np.array([13.0]),z=np.array([1.0])))
print(cluster_deltasigma.delta_sigma(log_mass=np.array([13.0]),z=np.array([1.0]), radius_center=2.0))
# Out:
# [0.00027175]
# [1.9362217e+12]

# %% [markdown]
# ## 8. Recipes
# Recipes put everything together into integrals used in statistics.
#
# Example: [`murata_binned_spec_z_deltasigma.py`](https://github.com/LSSTDESC/firecrown/blob/master/firecrown/models/cluster/recipes/murata_binned_spec_z_deltasigma.py)
#
# They define:
# - Redshift distribution
# - Mass distribution
# - Integrals for predictions
#
# Key method:
#
# ```
# def get_theory_prediction(
#     self,
#     cluster_theory: ClusterDeltaSigma,
#     average_on: None | ClusterProperty = None,
# ) -> Callable:
#     def theory_prediction(
#         mass, z, mass_proxy_limits, sky_area, radius_center,
#     ):
#         prediction = (
#             cluster_theory.comoving_volume(z, sky_area)
#             * cluster_theory.mass_function(mass, z)
#             * self.redshift_distribution.distribution()
#             * self.mass_distribution.distribution(mass, z, mass_proxy_limits)
#         )
#         if average_on is None:
#             raise ValueError("The property should be ClusterProperty.DELTASIGMA.")
#
#         if ClusterProperty.DELTASIGMA in ClusterProperty:
#             prediction *= cluster_theory.delta_sigma(mass, z, radius_center)
#         return prediction
#
#     return theory_prediction
# ```
#
# The final evaluation integrates this function:
#
# ```
# def evaluate_theory_prediction(self, cluster_theory, this_bin, sky_area, average_on=None):
#     self.integrator.integral_bounds = [
#         (cluster_theory.min_mass, cluster_theory.max_mass),
#         this_bin.z_edges,
#     ]
#     radius_center = this_bin.radius_center
#     self.integrator.extra_args = np.array(
#         [*this_bin.mass_proxy_edges, sky_area, radius_center]
#     )
#     theory_prediction = self.get_theory_prediction(cluster_theory, average_on)
#     prediction_wrapper = self.get_function_to_integrate(theory_prediction)
#     return self.integrator.integrate(prediction_wrapper)
# ```

# %%
def counts_deltasigma_prediction_from_sacc(path, survey_nm, pivot_mass, pivot_redshift, mu_p0, mu_p1, mu_p2, sigma_p0, sigma_p1, sigma_p2, mass_parameter=False):
    s_read = sacc.Sacc.load_fits(path)

    
    hmf = ccl.halos.MassFuncDespali16()
    min_mass, max_mass = 13., 16.
    min_z, max_z = 0.2, 0.8
    cluster_deltasigma = ClusterDeltaSigma((min_mass, max_mass), (min_z, max_z), hmf)
    cluster_abundance = ClusterAbundance((min_mass, max_mass), (min_z, max_z), hmf)
    cosmo_ccl = ccl.Cosmology(
    Omega_c=0.2052,
    Omega_b=0.0448,
    h=0.71,
    n_s=0.963,
    sigma8=0.8,
    Omega_k=0.0,
    Neff=3.044,
    m_nu=0.0,
    w0=-1.0,
    wa=0.0,
    T_CMB=2.7255
    )
    cluster_abundance.update_ingredients(cosmo_ccl)
    cluster_deltasigma.update_ingredients(cosmo_ccl)
    
    modeling_tools = ModelingTools(cluster_abundance = cluster_abundance, cluster_deltasigma=cluster_deltasigma)
    mds = MDS()
    mds.mass_distribution.pivot_mass = np.log(10**pivot_mass)
    mds.mass_distribution.pivot_redshift = pivot_redshift
    mds.mass_distribution.log1p_pivot_redshift = np.log1p(pivot_redshift)
    mds.mass_distribution.mu_p0 = mu_p0
    mds.mass_distribution.mu_p1 = mu_p1
    mds.mass_distribution.mu_p2 = mu_p2
    mds.mass_distribution.sigma_p0 = sigma_p0
    mds.mass_distribution.sigma_p1 = sigma_p1
    mds.mass_distribution.sigma_p2 = sigma_p2

    average_on = ClusterProperty.DELTASIGMA
    if mass_parameter:
        average_on |= ClusterProperty.MASS
    bin_cl_theory = BinnedClusterDeltaSigma(average_on, survey_nm, mds)
    bin_cl_theory.read(s_read)
    cluster_abundance.update_ingredients(cosmo_ccl)

    prediction = bin_cl_theory._compute_theory_vector(modeling_tools)
    data = bin_cl_theory.data_vector
    return data, prediction

# %% [markdown]
# Since we are defining the prediction function from the recipe in a python file, we had to set several parameter by hand that would be set by the cosmosis configuration files. We are also running some read and update methods that would be done by the statics object when passing this recipe. Now let us make a function call

# %%
firecrown_prediction = counts_deltasigma_prediction_from_sacc("cluster_redshift_richness_deltasigma_sacc_data.fits", "numcosmo_simulated_redshift_richness_deltasigma", 13.5, 0.5, 3.19, 2.0, 0.04, 0.5, 0.03, 0.01)
print(firecrown_prediction)
# Out:
# (DataVector([7.69456258e+13, 4.88340539e+13, 2.81903346e+13,
#             1.50059006e+13, 7.47930512e+12, 3.53993773e+12,
#             1.00140347e+14, 6.55628245e+13, 3.89231822e+13,
#             2.12128026e+13, 1.07748291e+13, 5.17584313e+12,
#             1.34220492e+14, 9.08611966e+13, 5.56101838e+13,
#             3.10956478e+13, 1.61233697e+13, 7.87047257e+12,
#             1.77097201e+14, 1.24101498e+14, 7.84585303e+13,
#             4.51150602e+13, 2.39296213e+13, 1.18910106e+13,
#             2.11761296e+14, 1.51156091e+14, 9.72921728e+13,
#             5.68390432e+13, 3.05459884e+13, 1.53374038e+13,
#             7.71643036e+13, 4.84365434e+13, 2.76951720e+13,
#             1.46279710e+13, 7.24643301e+12, 3.41352598e+12,
#             1.05885791e+14, 6.87778375e+13, 4.05337698e+13,
#             2.19516568e+13, 1.10926783e+13, 5.30669208e+12,
#             1.45397707e+14, 9.80214669e+13, 5.97580891e+13,
#             3.33013800e+13, 1.72188395e+13, 8.38660449e+12,
#             1.75263485e+14, 1.20810536e+14, 7.51810033e+13,
#             4.26365729e+13, 2.23594293e+13, 1.10113468e+13,
#             2.21456946e+14, 1.57317545e+14, 1.00733347e+14,
#             5.85576778e+13, 3.13332070e+13, 1.56764845e+13,
#             8.34199242e+13, 5.21070560e+13, 2.96624971e+13,
#             1.56088367e+13, 7.70914884e+12, 3.62291060e+12,
#             1.10593314e+14, 7.12687045e+13, 4.17058172e+13,
#             2.24538275e+13, 1.12933430e+13, 5.38299061e+12,
#             1.50049638e+14, 1.00243089e+14, 6.06155759e+13,
#             3.35503416e+13, 1.72542828e+13, 8.36891576e+12,
#             1.91362716e+14, 1.31968078e+14, 8.22112291e+13,
#             4.66871962e+13, 2.45177912e+13, 1.20894630e+13,
#             2.22275127e+14, 1.55390605e+14, 9.79660162e+13,
#             5.61735461e+13, 2.97191577e+13, 1.47361147e+13,
#             8.64121414e+13, 5.34615929e+13, 3.01817130e+13,
#             1.57745762e+13, 7.74940740e+12, 3.62673963e+12,
#             1.23282123e+14, 7.91964210e+13, 4.62085026e+13,
#             2.48146921e+13, 1.24547922e+13, 5.92680714e+12,
#             1.55527033e+14, 1.02944160e+14, 6.17299829e+13,
#             3.39279411e+13, 1.73506973e+13, 8.37891855e+12,
#             2.02269418e+14, 1.37738910e+14, 8.47631182e+13,
#             4.76182338e+13, 2.47831636e+13, 1.21330985e+13,
#             2.90062694e+14, 2.07032443e+14, 1.33156045e+14,
#             7.76983412e+13, 4.17007662e+13, 2.09122121e+13]), TheoryVector([2.19689942e+13, 1.20014263e+13, 6.10544777e+12,
#               2.93577582e+12, 1.35115650e+12, 6.01125461e+11,
#               2.59041401e+13, 1.43635063e+13, 7.39540031e+12,
#               3.58966961e+12, 1.66419335e+12, 7.44590417e+11,
#               3.04946477e+13, 1.71740788e+13, 8.95500746e+12,
#               4.39012875e+12, 2.05104543e+12, 9.23171060e+11,
#               3.57733707e+13, 2.04740870e+13, 1.08175711e+13,
#               5.35883015e+12, 2.52397638e+12, 1.14318026e+12,
#               4.18102658e+13, 2.43303052e+13, 1.30330720e+13,
#               6.52726803e+12, 3.10055071e+12, 1.41359729e+12,
#               2.31651465e+13, 1.26366689e+13, 6.42118998e+12,
#               3.08481205e+12, 1.41875663e+12, 6.30858612e+11,
#               2.73206190e+13, 1.51259228e+13, 7.77838764e+12,
#               3.77193260e+12, 1.74738684e+12, 7.81360848e+11,
#               3.21721881e+13, 1.80899081e+13, 9.42026532e+12,
#               4.61348229e+12, 2.15368036e+12, 9.68769844e+11,
#               3.77532527e+13, 2.15709467e+13, 1.13813579e+13,
#               5.63195470e+12, 2.65036212e+12, 1.19963444e+12,
#               4.41370228e+13, 2.56389452e+13, 1.37139235e+13,
#               6.86023224e+12, 3.25574893e+12, 1.48330981e+12,
#               2.43392528e+13, 1.32701255e+13, 6.74021256e+12,
#               3.23700008e+12, 1.48836820e+12, 6.61680069e+11,
#               2.87057774e+13, 1.58836192e+13, 8.16421104e+12,
#               3.95757759e+12, 1.83286854e+12, 8.19404667e+11,
#               3.38066720e+13, 1.89970441e+13, 9.88760493e+12,
#               4.84041127e+12, 2.25891172e+12, 1.01585989e+12,
#               3.96744789e+13, 2.26532607e+13, 1.19457328e+13,
#               5.90861564e+12, 2.77960135e+12, 1.25779740e+12,
#               4.63866147e+13, 2.69257926e+13, 1.43933946e+13,
#               7.19661021e+12, 3.41408779e+12, 1.55499018e+12,
#               2.54957844e+13, 1.39030411e+13, 7.06264503e+12,
#               3.39220880e+12, 1.55986100e+12, 6.93507560e+11,
#               3.00652851e+13, 1.66382557e+13, 8.55308710e+12,
#               4.14646098e+12, 1.92048111e+12, 8.58619681e+11,
#               3.54052715e+13, 1.98976987e+13, 1.03573744e+13,
#               5.07076731e+12, 2.36655247e+12, 1.06431553e+12,
#               4.15469174e+13, 2.37244345e+13, 1.25114808e+13,
#               6.18879268e+12, 2.91153178e+12, 1.31754138e+12,
#               4.85702948e+13, 2.81946696e+13, 1.50722650e+13,
#               7.53627085e+12, 3.57530778e+12, 1.62844945e+12]))

# %% [markdown]
# ## 10. SACC data
# SACC stores data with **tags for each data type**:
# - Cluster number counts: 3 tracers (`richness`, `redshift`, `survey`)
# - Shear: 4 tracers (the same 3 plus `radius center`)
#
# Each data point must be added with its tracer information.
#
# Example: opening a SACC file to inspect contents.

# %%
import pprint
s = sacc.Sacc.load_fits("cluster_redshift_richness_deltasigma_sacc_data.fits")
pprint.pprint(s.tracers)
print(f"\n\n\n")
pprint.pprint(s.data)
# Out:
# {np.str_('bin_radius_0'): <sacc.tracers.BinRadiusTracer object at 0x7fa82c42f9d0>,
#  np.str_('bin_radius_1'): <sacc.tracers.BinRadiusTracer object at 0x7fa82c42f7d0>,
#  np.str_('bin_radius_2'): <sacc.tracers.BinRadiusTracer object at 0x7fa82c42ccd0>,
#  np.str_('bin_radius_3'): <sacc.tracers.BinRadiusTracer object at 0x7fa82c42de50>,
#  np.str_('bin_radius_4'): <sacc.tracers.BinRadiusTracer object at 0x7fa82c42c4d0>,
#  np.str_('bin_radius_5'): <sacc.tracers.BinRadiusTracer object at 0x7fa82c4b40d0>,
#  np.str_('bin_z_0'): <sacc.tracers.BinZTracer object at 0x7fa86aa102f0>,
#  np.str_('bin_z_1'): <sacc.tracers.BinZTracer object at 0x7fa83423b930>,
#  np.str_('bin_z_2'): <sacc.tracers.BinZTracer object at 0x7fa8358316a0>,
#  np.str_('bin_z_3'): <sacc.tracers.BinZTracer object at 0x7fa835831b70>,
#  np.str_('numcosmo_simulated_redshift_richness_deltasigma'): <sacc.tracers.SurveyTracer object at 0x7fa82bddd950>,
#  np.str_('rich_0'): <sacc.tracers.BinRichnessTracer object at 0x7fa835831940>,
#  np.str_('rich_1'): <sacc.tracers.BinRichnessTracer object at 0x7fa8358318d0>,
#  np.str_('rich_2'): <sacc.tracers.BinRichnessTracer object at 0x7fa82bc14d70>,
#  np.str_('rich_3'): <sacc.tracers.BinRichnessTracer object at 0x7fa82bc15710>,
#  np.str_('rich_4'): <sacc.tracers.BinRichnessTracer object at 0x7fa82bc17690>}
#
#
#
#
# [DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0')), value=284, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1')), value=113, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2')), value=48, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3')), value=7, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4')), value=3, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0')), value=408, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1')), value=177, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2')), value=58, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3')), value=13, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4')), value=4, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0')), value=600, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1')), value=220, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2')), value=85, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3')), value=10, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4')), value=5, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0')), value=671, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1')), value=222, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2')), value=72, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3')), value=13, ),
#  DataPoint(data_type='cluster_counts', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4')), value=3, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0')), value=13.985544313892047, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1')), value=14.179647444352389, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2')), value=14.404224205360313, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3')), value=14.632081696555048, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4')), value=14.76520424395752, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0')), value=13.952495375023815, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1')), value=14.183835195384376, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2')), value=14.428771402496784, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3')), value=14.581667458478101, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4')), value=14.783689856638354, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0')), value=13.977996169527648, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1')), value=14.180395899336261, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2')), value=14.412584828047207, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3')), value=14.602399864213547, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4')), value=14.738762684834342, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0')), value=13.968347389900194, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1')), value=14.226468785894529, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2')), value=14.395112731058411, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3')), value=14.599973442528412, ),
#  DataPoint(data_type='cluster_mean_log_mass', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4')), value=14.920496421921484, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0'), np.str_('bin_radius_0')), value=76945625814891.31, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0'), np.str_('bin_radius_1')), value=48834053862143.875, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0'), np.str_('bin_radius_2')), value=28190334553350.867, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0'), np.str_('bin_radius_3')), value=15005900595270.99, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0'), np.str_('bin_radius_4')), value=7479305117557.749, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_0'), np.str_('bin_radius_5')), value=3539937727491.163, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1'), np.str_('bin_radius_0')), value=100140347168216.48, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1'), np.str_('bin_radius_1')), value=65562824522118.56, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1'), np.str_('bin_radius_2')), value=38923182175098.41, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1'), np.str_('bin_radius_3')), value=21212802641933.023, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1'), np.str_('bin_radius_4')), value=10774829065300.896, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_1'), np.str_('bin_radius_5')), value=5175843125147.183, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2'), np.str_('bin_radius_0')), value=134220492461829.69, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2'), np.str_('bin_radius_1')), value=90861196641141.4, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2'), np.str_('bin_radius_2')), value=55610183781039.96, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2'), np.str_('bin_radius_3')), value=31095647826330.7, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2'), np.str_('bin_radius_4')), value=16123369698274.365, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_2'), np.str_('bin_radius_5')), value=7870472565070.453, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3'), np.str_('bin_radius_0')), value=177097201268511.25, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3'), np.str_('bin_radius_1')), value=124101497797609.27, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3'), np.str_('bin_radius_2')), value=78458530296256.33, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3'), np.str_('bin_radius_3')), value=45115060200896.04, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3'), np.str_('bin_radius_4')), value=23929621289138.53, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_3'), np.str_('bin_radius_5')), value=11891010639468.527, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4'), np.str_('bin_radius_0')), value=211761296312617.25, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4'), np.str_('bin_radius_1')), value=151156090768274.66, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4'), np.str_('bin_radius_2')), value=97292172844637.95, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4'), np.str_('bin_radius_3')), value=56839043247341.78, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4'), np.str_('bin_radius_4')), value=30545988353128.16, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_0'), np.str_('rich_4'), np.str_('bin_radius_5')), value=15337403755824.537, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0'), np.str_('bin_radius_0')), value=77164303626740.48, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0'), np.str_('bin_radius_1')), value=48436543431383.69, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0'), np.str_('bin_radius_2')), value=27695172000885.57, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0'), np.str_('bin_radius_3')), value=14627971039696.955, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0'), np.str_('bin_radius_4')), value=7246433006910.568, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_0'), np.str_('bin_radius_5')), value=3413525978690.997, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1'), np.str_('bin_radius_0')), value=105885791105862.83, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1'), np.str_('bin_radius_1')), value=68777837481654.6, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1'), np.str_('bin_radius_2')), value=40533769759204.08, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1'), np.str_('bin_radius_3')), value=21951656775228.504, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1'), np.str_('bin_radius_4')), value=11092678277649.123, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_1'), np.str_('bin_radius_5')), value=5306692079321.965, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2'), np.str_('bin_radius_0')), value=145397706749267.84, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2'), np.str_('bin_radius_1')), value=98021466896386.52, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2'), np.str_('bin_radius_2')), value=59758089130742.14, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2'), np.str_('bin_radius_3')), value=33301380042040.09, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2'), np.str_('bin_radius_4')), value=17218839469710.266, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_2'), np.str_('bin_radius_5')), value=8386604490007.559, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3'), np.str_('bin_radius_0')), value=175263485071946.3, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3'), np.str_('bin_radius_1')), value=120810536083427.6, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3'), np.str_('bin_radius_2')), value=75181003271781.48, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3'), np.str_('bin_radius_3')), value=42636572948256.49, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3'), np.str_('bin_radius_4')), value=22359429280146.895, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_3'), np.str_('bin_radius_5')), value=11011346792995.664, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4'), np.str_('bin_radius_0')), value=221456946351164.84, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4'), np.str_('bin_radius_1')), value=157317545474909.72, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4'), np.str_('bin_radius_2')), value=100733347198962.28, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4'), np.str_('bin_radius_3')), value=58557677777577.484, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4'), np.str_('bin_radius_4')), value=31333207038412.14, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_1'), np.str_('rich_4'), np.str_('bin_radius_5')), value=15676484523021.021, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0'), np.str_('bin_radius_0')), value=83419924170599.88, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0'), np.str_('bin_radius_1')), value=52107056013076.28, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0'), np.str_('bin_radius_2')), value=29662497080656.11, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0'), np.str_('bin_radius_3')), value=15608836672470.96, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0'), np.str_('bin_radius_4')), value=7709148842391.884, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_0'), np.str_('bin_radius_5')), value=3622910597817.409, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1'), np.str_('bin_radius_0')), value=110593313921905.02, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1'), np.str_('bin_radius_1')), value=71268704484950.2, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1'), np.str_('bin_radius_2')), value=41705817184425.05, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1'), np.str_('bin_radius_3')), value=22453827524074.742, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1'), np.str_('bin_radius_4')), value=11293342962772.707, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_1'), np.str_('bin_radius_5')), value=5382990608491.627, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2'), np.str_('bin_radius_0')), value=150049638217084.44, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2'), np.str_('bin_radius_1')), value=100243088540014.83, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2'), np.str_('bin_radius_2')), value=60615575928808.555, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2'), np.str_('bin_radius_3')), value=33550341641466.56, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2'), np.str_('bin_radius_4')), value=17254282772983.664, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_2'), np.str_('bin_radius_5')), value=8368915763928.853, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3'), np.str_('bin_radius_0')), value=191362715583939.3, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3'), np.str_('bin_radius_1')), value=131968077519619.47, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3'), np.str_('bin_radius_2')), value=82211229069849.92, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3'), np.str_('bin_radius_3')), value=46687196229996.445, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3'), np.str_('bin_radius_4')), value=24517791181770.797, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_3'), np.str_('bin_radius_5')), value=12089463049268.922, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4'), np.str_('bin_radius_0')), value=222275127330276.62, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4'), np.str_('bin_radius_1')), value=155390604557463.03, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4'), np.str_('bin_radius_2')), value=97966016229276.45, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4'), np.str_('bin_radius_3')), value=56173546083934.52, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4'), np.str_('bin_radius_4')), value=29719157672131.47, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_2'), np.str_('rich_4'), np.str_('bin_radius_5')), value=14736114748848.406, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0'), np.str_('bin_radius_0')), value=86412141437482.72, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0'), np.str_('bin_radius_1')), value=53461592860007.86, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0'), np.str_('bin_radius_2')), value=30181712996042.95, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0'), np.str_('bin_radius_3')), value=15774576186500.117, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0'), np.str_('bin_radius_4')), value=7749407399888.121, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_0'), np.str_('bin_radius_5')), value=3626739630683.0737, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1'), np.str_('bin_radius_0')), value=123282123401473.53, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1'), np.str_('bin_radius_1')), value=79196421015822.44, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1'), np.str_('bin_radius_2')), value=46208502607383.65, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1'), np.str_('bin_radius_3')), value=24814692081021.418, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1'), np.str_('bin_radius_4')), value=12454792248211.246, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_1'), np.str_('bin_radius_5')), value=5926807143645.881, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2'), np.str_('bin_radius_0')), value=155527032635942.62, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2'), np.str_('bin_radius_1')), value=102944159838543.69, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2'), np.str_('bin_radius_2')), value=61729982937813.42, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2'), np.str_('bin_radius_3')), value=33927941096363.027, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2'), np.str_('bin_radius_4')), value=17350697312436.723, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_2'), np.str_('bin_radius_5')), value=8378918548065.512, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3'), np.str_('bin_radius_0')), value=202269418237474.88, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3'), np.str_('bin_radius_1')), value=137738909863696.33, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3'), np.str_('bin_radius_2')), value=84763118184454.28, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3'), np.str_('bin_radius_3')), value=47618233795281.5, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3'), np.str_('bin_radius_4')), value=24783163598345.195, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_3'), np.str_('bin_radius_5')), value=12133098515747.322, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4'), np.str_('bin_radius_0')), value=290062693792469.5, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4'), np.str_('bin_radius_1')), value=207032443296398.47, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4'), np.str_('bin_radius_2')), value=133156044781934.8, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4'), np.str_('bin_radius_3')), value=77698341223810.98, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4'), np.str_('bin_radius_4')), value=41700766247612.125, ),
#  DataPoint(data_type='cluster_shear', tracers=(np.str_('numcosmo_simulated_redshift_richness_deltasigma'), np.str_('bin_z_3'), np.str_('rich_4'), np.str_('bin_radius_5')), value=20912212112999.15, )]
