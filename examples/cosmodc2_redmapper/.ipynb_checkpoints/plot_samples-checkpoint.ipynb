# %%
# %matplotlib inline
import pandas as pd
from getdist import plots
from getdist import MCSamples

import matplotlib.pyplot as plt
import numpy as np
from cosmosis.postprocess import parser
from cosmosis.postprocessing.inputs import read_input
from cosmosis.postprocessing.postprocess import postprocessor_for_sampler
from cosmosis.postprocessing.plots import (
    MetropolisHastingsPlots2D,
    MetropolisHastingsPlots1D,
)


import math
from IPython.display import display, Math

# %% [markdown]
# ## BASELINE

# %%
import sys
sys.path.append("../../")
from clpipeline.utils.cosmosis_mcmc_plots import plot_triangle, ChainStyle, PlotConfig, chains_to_fits

# ── Paths ─────────────────────────────────────────────────────────────────────
DIR = "/sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline"

def chain(subdir, run):
    return f"{DIR}/{subdir}/outputs_{run}/output_rp/number_counts_samples.txt"

SUBDIRS = {
    "full":    "cosmodc2_redmapper_full_analysis",
    "lensing": "cosmodc2_redmapper_lensing",
    "counts":  "cosmodc2_redmapper_counts",
}

paths_mor  = [chain(SUBDIRS[k], "mor")  for k in ("full", "lensing", "counts")]
paths_both = [chain(SUBDIRS[k], "both") for k in ("full", "lensing", "counts")]

# ── Parameters ────────────────────────────────────────────────────────────────
PARAMS_MOR = [
    (r"\mu_0",     3.34),
    (r"\mu_m",     0.958236982),
    (r"\mu_z",    -0.0192802),
    (r"\sigma_0",  0.562317194),
    (r"\sigma_m",  0.04552506),
    (r"\sigma_z",  -0.0445),
]

PARAMS_BOTH = [
    (r"\Omega_c",  0.22),
    (r"\sigma_8",  0.80),
    *PARAMS_MOR,
]

# ── Chain styles ──────────────────────────────────────────────────────────────
#   filled=True  → filled contours + solid outline  (the "money" combined chain)
#   filled=False → solid/dashed lines only           (individual probes)

STYLES_3 = [
    ChainStyle("Counts + Lensing", filled=True,  linestyle="--", fill_alpha=0.62, linewidth=1.6),
    ChainStyle("Lensing",          filled=False, linestyle="-",   linewidth=1.6),
    ChainStyle("Cluster Counts",   filled=False, linestyle="-",  linewidth=1.6),
]

# ── Config ────────────────────────────────────────────────────────────────────
cfg_6par = PlotConfig(figsize=7, output_dir="./figures")
cfg_8par = PlotConfig(figsize=8, output_dir="./figures")

# ── Plot ──────────────────────────────────────────────, save=False────────────────────────
samples_mor  = plot_triangle(paths_mor,  PARAMS_MOR,  STYLES_3, name="mor_baseline",      config=cfg_6par, save=False)
samples_both = plot_triangle(paths_both, PARAMS_BOTH, STYLES_3, name="full_fit_baseline",  config=cfg_8par, save=False)


# chains_to_fits(
#     samples    = samples_mor,
#     params     = PARAMS_MOR,
#     labels     = ["full", "lensing", "counts"],
#     output_dir = "./",
# )
# Out:
# /sps/lsst/groups/clusters/cl_pipeline_project/conda_envs/firecrown_developer_clp/lib/python3.13/site-packages/ceci/__init__.py:12: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound
# LOADING CHAIN FROM FILE:  /sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_full_analysis/outputs_mor/output_rp/number_counts_samples.txt
# Removed no burn in
#   Counts + Lensing: 37,100 samples  (/sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_full_analysis/outputs_mor/output_rp/number_counts_samples.txt)
# LOADING CHAIN FROM FILE:  /sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_lensing/outputs_mor/output_rp/number_counts_samples.txt
# Removed no burn in
#   Lensing: 69,300 samples  (/sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_lensing/outputs_mor/output_rp/number_counts_samples.txt)
# LOADING CHAIN FROM FILE:  /sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_counts/outputs_mor/output_rp/number_counts_samples.txt
# Removed no burn in
#   Cluster Counts: 70,000 samples  (/sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_counts/outputs_mor/output_rp/number_counts_samples.txt)
# ── Counts + Lensing ──
# $\displaystyle \mu_0: \mu_0 = 3.335\pm 0.047$
# $\displaystyle \mu_m: \mu_m = 0.939\pm 0.041$
# $\displaystyle \mu_z: \mu_z = -0.29\pm 0.21$
# $\displaystyle \sigma_0: \sigma_0 = 0.536^{+0.030}_{-0.026}$
# $\displaystyle \sigma_m: \sigma_m = 0.025^{+0.037}_{-0.029}$
# $\displaystyle \sigma_z: \sigma_z = 0.46\pm 0.19$
# ── Lensing ──
# $\displaystyle \mu_0: \mu_0 = 2.86^{+0.89}_{-0.22}$
# $\displaystyle \mu_m: \mu_m = 0.62^{+0.39}_{-0.59}$
# $\displaystyle \mu_z: \mu_z = 0.18^{+0.67}_{-0.44}$
# $\displaystyle \sigma_0: \sigma_0 = 0.522^{+0.12}_{-0.065}$
# $\displaystyle \sigma_m: \sigma_m = 0.020^{+0.089}_{-0.055}$
# $\displaystyle \sigma_z: \sigma_z = 0.04^{+0.18}_{-0.30}$
# ── Cluster Counts ──
# $\displaystyle \mu_0: \mu_0 = 2.67\pm 0.59$
# $\displaystyle \mu_m: \mu_m = 0.60^{+0.48}_{-0.56}$
# $\displaystyle \mu_z: \mu_z = -0.06^{+0.32}_{-0.36}$
# $\displaystyle \sigma_0: \sigma_0 = 0.79^{+0.32}_{-0.26}$
# $\displaystyle \sigma_m: \sigma_m = -0.005^{+0.12}_{-0.073}$
# $\displaystyle \sigma_z: \sigma_z = 0.07^{+0.24}_{-0.40}$
# LOADING CHAIN FROM FILE:  /sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_full_analysis/outputs_both/output_rp/number_counts_samples.txt
# Removed no burn in
#   Counts + Lensing: 37,100 samples  (/sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_full_analysis/outputs_both/output_rp/number_counts_samples.txt)
# LOADING CHAIN FROM FILE:  /sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_lensing/outputs_both/output_rp/number_counts_samples.txt
# Removed no burn in
#   Lensing: 79,800 samples  (/sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_lensing/outputs_both/output_rp/number_counts_samples.txt)
# LOADING CHAIN FROM FILE:  /sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_counts/outputs_both/output_rp/number_counts_samples.txt
# Removed no burn in
#   Cluster Counts: 68,600 samples  (/sps/lsst/users/ebarroso/CLPipeline/examples/cosmodc2_redmapper/baseline/cosmodc2_redmapper_counts/outputs_both/output_rp/number_counts_samples.txt)
# ── Counts + Lensing ──
# $\displaystyle \Omega_c: \Omega_c = 0.242^{+0.037}_{-0.044}$
# $\displaystyle \sigma_8: \sigma_8 = 0.776^{+0.035}_{-0.050}$
# $\displaystyle \mu_0: \mu_0 = 3.41^{+0.20}_{-0.12}$
# $\displaystyle \mu_m: \mu_m = 0.996^{+0.11}_{-0.088}$
# $\displaystyle \mu_z: \mu_z = -0.05\pm 0.41$
# $\displaystyle \sigma_0: \sigma_0 = 0.481^{+0.11}_{-0.090}$
# $\displaystyle \sigma_m: \sigma_m = 0.013^{+0.044}_{-0.027}$
# $\displaystyle \sigma_z: \sigma_z = 0.41^{+0.24}_{-0.21}$
# ── Lensing ──
# $\displaystyle \Omega_c: \Omega_c = 0.260\pm 0.058$
# $\displaystyle \sigma_8: \sigma_8 = 0.797\pm 0.056$
# $\displaystyle \mu_0: \mu_0 = 2.91^{+0.53}_{-0.20}$
# $\displaystyle \mu_m: \mu_m = 0.58^{+0.31}_{-0.21}$
# $\displaystyle \mu_z: \mu_z = -0.02\pm 0.57$
# $\displaystyle \sigma_0: \sigma_0 = 0.569^{+0.066}_{-0.050}$
# $\displaystyle \sigma_m: \sigma_m = 0.053^{+0.055}_{-0.017}$
# $\displaystyle \sigma_z: \sigma_z = 0.08\pm 0.22$
# ── Cluster Counts ──
# $\displaystyle \Omega_c: \Omega_c = 0.261^{+0.086}_{-0.041}$
# $\displaystyle \sigma_8: \sigma_8 = 0.784^{+0.036}_{-0.081}$
# $\displaystyle \mu_0: \mu_0 = 2.61\pm 0.61$
# $\displaystyle \mu_m: \mu_m = 0.62^{+0.45}_{-0.34}$
# $\displaystyle \mu_z: \mu_z = 0.13\pm 0.48$
# $\displaystyle \sigma_0: \sigma_0 = 0.84^{+0.30}_{-0.21}$
# $\displaystyle \sigma_m: \sigma_m = 0.001^{+0.11}_{-0.090}$
# $\displaystyle \sigma_z: \sigma_z = 0.02^{+0.22}_{-0.44}$
#   Saved 37,100 samples × 6 params → full.fits
#   Saved 69,300 samples × 6 params → lensing.fits
#   Saved 70,000 samples × 6 params → counts.fits
# [PosixPath('full.fits'), PosixPath('lensing.fits'), PosixPath('counts.fits')]
