# %%
import clmm
import numpy as np
import matplotlib.pyplot as plt
from clmm import Cosmology
import h5py

# %%
true_shear = '/sps/lsst/groups/clusters/cl_pipeline_project/TXPipe_data/cosmodc2/outputs-full-2026/cluster_shear_catalogs.hdf5'

# with h5py.File(true_shear, 'r') as f:
#     # List all groups/datasets
#     print("Keys:", list(f.keys()))
    
#     # Access a dataset
#     true_g1 = np.array(f['index']['g1'])
#     true_distance = np.array(f['index']['distance_arcmin'])



# # Plotting
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.scatter(true_distance, true_g1, s=1, color='blue', alpha=0.5)
# plt.title('True Shear 20deg2')
# plt.xlabel('Distance (arcmin)')
# plt.ylabel('Shear g1')
# plt.subplot(1, 2, 2)
# plt.tight_layout()
# plt.show()
# # Plotting the histograms
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.hist(true_g1, bins=50, color='blue', alpha=0.7)
# plt.title('Histogram of True Shear g1 20deg2')
# plt.xlabel('Shear g1')
# plt.ylabel('Frequency')
# plt.subplot(1, 2, 2)

# plt.ylabel('Frequency')
# plt.tight_layout()
# plt.show()

# %%
# print("True shear g1 mean:", np.mean(true_g1))
# print("True shear g1 std:", np.std(true_g1))

# print("True shear g1 min:", np.min(true_g1))
# print("True shear g1 max:", np.max(true_g1))

# print("Number of shear higher than 0.1", np.sum(true_g1 > 0.1))
# print("Number of shear lower than -0.1", np.sum(true_g1 < -0.1))

# print("Total number of sorces", len(true_g1))
# print("Percentage of false g1 higher than 0.1", np.sum(true_g1 > 0.1)/len(true_g1))

# %% [markdown]
# ## Gt

# %%
import sacc
sacc_file_20_true = '/sps/lsst/groups/clusters/cl_pipeline_project/TXPipe_data/cosmodc2/outputs-full-gt-2026/cluster_sacc_catalog.sacc'

t1 = sacc.Sacc.load_fits(sacc_file_20_true)
print(t1.tracers)
#print(t1.data)
data2 = []
radius2 = []
for i in range(0,12):
    trac = ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_3', f'radius_{i}')
    data2.append(t1.get_data_points(sacc.data_types.standard_types.cluster_shear, trac)[0].value)
    radius = t1.tracers[f'radius_{i}'].center
    radius2.append(radius)
plt.plot(radius2, data2, label='True Shear')




plt.title('Cluster Profile for zbin3 and richbin3')
plt.xlabel('Distance (arcmin)')
plt.ylabel('$g_t$')

plt.legend()
print(f'z_bin is [{t1.get_tracer('bin_z_1').lower}, {t1.get_tracer('bin_z_1').upper}] \n')
print(f'rich_bin is [{10*(t1.get_tracer('bin_rich_1').lower)}, {10*(t1.get_tracer('bin_rich_1').upper)}] \n')
print(f'z_bin is [{t1.get_tracer('bin_z_1').lower}, {t1.get_tracer('bin_z_1').upper}] \n')
print(f'rich_bin is [{10*(t1.get_tracer('bin_rich_3').lower)}, {10*(t1.get_tracer('bin_rich_3').upper)}] \n')
print(f'z_bin is [{t1.get_tracer('bin_z_1').lower}, {t1.get_tracer('bin_z_1').upper}] \n')
print(f'rich_bin is [{10**(t1.get_tracer('bin_rich_3').lower)}, {10**(t1.get_tracer('bin_rich_3').upper)}] \n')
# Out:
# {np.str_('bin_z_0'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a2caf540>, np.str_('bin_rich_0'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f05a110e210>, np.str_('bin_rich_1'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f090c134520>, np.str_('bin_rich_2'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f090c1345d0>, np.str_('bin_rich_3'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f05a2b93cf0>, np.str_('bin_z_1'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3dc3af0>, np.str_('bin_z_2'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3dc38c0>, np.str_('bin_z_3'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3b82ba0>, np.str_('bin_z_4'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3b81ef0>, np.str_('bin_z_5'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3b81e80>, np.str_('bin_z_6'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3b83930>, np.str_('radius_0'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3b7a3d0>, np.str_('radius_1'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3b7a9d0>, np.str_('radius_2'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3b7a8d0>, np.str_('radius_3'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3873ad0>, np.str_('radius_4'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3873150>, np.str_('radius_5'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3872150>, np.str_('radius_6'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3871ad0>, np.str_('radius_7'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3872cd0>, np.str_('radius_8'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3872dd0>, np.str_('radius_9'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3872d50>, np.str_('radius_10'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3871b50>, np.str_('radius_11'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3871d50>, np.str_('cosmodc2-20deg2-CL'): <sacc.tracers.survey.SurveyTracer object at 0x7f05a3bcafd0>}
# z_bin is [0.3, 0.4]
#
# rich_bin is [15.440680443502757, 18.45098040014257]
#
# z_bin is [0.3, 0.4]
#
# rich_bin is [20.0, 23.010299956639813]
#
# z_bin is [0.3, 0.4]
#
# rich_bin is [100.0, 200.00000000000003]

# %% [markdown]
# ## Delta sigma

# %%
import sacc
sacc_file_20_true = '/sps/lsst/groups/clusters/cl_pipeline_project/TXPipe_data/cosmodc2/outputs-full-10mpc-2026/cluster_sacc_catalog.sacc'

t1 = sacc.Sacc.load_fits(sacc_file_20_true)
print(t1.tracers)
#print(t1.data)
data2 = []
radius2 = []
for i in range(0,15):
    trac = ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_1', f'radius_{i}')
    data2.append(t1.get_data_points(sacc.data_types.standard_types.cluster_delta_sigma, trac)[0].value)
    radius = t1.tracers[f'radius_{i}'].center
    radius2.append(radius)
plt.plot(radius2, data2, label='True Shear')




plt.title('20deg2 SACC Cluster Profile for zbin1 and richbin3')
plt.xlabel('Distance (Mpc)')
plt.ylabel('$\Delta \Sigma $')

plt.legend()
print(f'z_bin is [{t1.get_tracer('bin_z_1').lower}, {t1.get_tracer('bin_z_1').upper}] \n')
print(f'rich_bin is [{10*(t1.get_tracer('bin_rich_1').lower)}, {10*(t1.get_tracer('bin_rich_1').upper)}] \n')
print(f'z_bin is [{t1.get_tracer('bin_z_1').lower}, {t1.get_tracer('bin_z_1').upper}] \n')
print(f'rich_bin is [{10*(t1.get_tracer('bin_rich_3').lower)}, {10*(t1.get_tracer('bin_rich_3').upper)}] \n')
print(f'z_bin is [{t1.get_tracer('bin_z_1').lower}, {t1.get_tracer('bin_z_1').upper}] \n')
print(f'rich_bin is [{10**(t1.get_tracer('bin_rich_3').lower)}, {10**(t1.get_tracer('bin_rich_3').upper)}] \n')
# Out:
# {np.str_('bin_z_0'): <sacc.tracers.clusters.BinZTracer object at 0x7f05ac4e8490>, np.str_('bin_rich_0'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f05ac44a8b0>, np.str_('bin_rich_1'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f05a385fbf0>, np.str_('bin_rich_2'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f05ac4e9ae0>, np.str_('bin_rich_3'): <sacc.tracers.clusters.BinRichnessTracer object at 0x7f05a3dc4c00>, np.str_('bin_z_1'): <sacc.tracers.clusters.BinZTracer object at 0x7f090c335e50>, np.str_('bin_z_2'): <sacc.tracers.clusters.BinZTracer object at 0x7f090c335750>, np.str_('bin_z_3'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3d32a80>, np.str_('bin_z_4'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3d30050>, np.str_('bin_z_5'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3bb6c10>, np.str_('bin_z_6'): <sacc.tracers.clusters.BinZTracer object at 0x7f05a3bb6190>, np.str_('radius_0'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3bb58d0>, np.str_('radius_1'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3bb7850>, np.str_('radius_2'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f090c1a3450>, np.str_('radius_3'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3866810>, np.str_('radius_4'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a38668d0>, np.str_('radius_5'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05ac487d80>, np.str_('radius_6'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f090c134680>, np.str_('radius_7'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3b4ad50>, np.str_('radius_8'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3b4b2f0>, np.str_('radius_9'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3ddd7f0>, np.str_('radius_10'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3868a50>, np.str_('radius_11'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3dae450>, np.str_('radius_12'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3dae6d0>, np.str_('radius_13'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a386a050>, np.str_('radius_14'): <sacc.tracers.clusters.BinRadiusTracer object at 0x7f05a3868650>, np.str_('cosmodc2-20deg2-CL'): <sacc.tracers.survey.SurveyTracer object at 0x7f05a3da60d0>}
# z_bin is [0.3, 0.4]
#
# rich_bin is [15.440680443502757, 18.45098040014257]
#
# z_bin is [0.3, 0.4]
#
# rich_bin is [20.0, 23.010299956639813]
#
# z_bin is [0.3, 0.4]
#
# rich_bin is [100.0, 200.00000000000003]

# %% [markdown]
# ### Constantin Data

# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import sys
import matplotlib.pyplot as plt
sys.path.append('/sps/lsst/users/ebarroso/CLCosmo_Sim')
import _redshift_richness_bins as analysis

plt.figure(figsize=(7,4))
index = 12
fmt = ['-', '--', '.']
suff = '_full_coverage'
path_to_data = '/sps/lsst/users/ebarroso/CLCosmo_Sim_database/data/'
data = np.load(path_to_data + f'stacked_esd_profiles_redmapper_true{suff}.pkl', allow_pickle=True)
profiles = data['stacked profile']
covariances = data['stacked covariance']
Z_bin = analysis.Z_bin
Obs_bin = analysis.Obs_bin
n_z_bin = len(Z_bin) 
n_m_bin = len(Obs_bin) 
fig, axs = plt.subplots(1,len(Z_bin), figsize = (10,2))
fig.subplots_adjust(wspace=0, hspace=0)
for i, z_bin in enumerate(Z_bin):
    for j, m_bin in enumerate(Obs_bin):

            label_z =   f'{z_bin[0]:.1f} < z < {z_bin[1]:.1f}'
            label_M = f'{m_bin[0]:.0f} < ' + r'$\lambda$' +f' < {m_bin[1]:.0f}'
            mask_z = (profiles['z_mean'] > z_bin[0])*(profiles['z_mean'] < z_bin[1])
            mask_m = (profiles['obs_mean'] > m_bin[0])*(profiles['obs_mean'] < m_bin[1])
            index = np.arange(len(profiles))
            index_cut = index[mask_m * mask_z]
            f_cut = profiles[index_cut]
            cov = np.array(covariances['cov_t'][index_cut])
            err = cov.T.diagonal()**.5
            axs[i].errorbar(f_cut['radius'][0], f_cut['gt'][0] , err[0],
                            marker = 'o',fmt = '-', elinewidth = 2,  markersize = 2, markerfacecolor = None, label = label_M)
            axs[i].set_ylim(1e12, 3e14)
            axs[i].set_xlim(0.4, 12)
            axs[i].set_xscale('log')
            axs[i].set_yscale('log')
            axs[i].vlines(1, 0, 1e19, ls='--', color='k')
            axs[i].tick_params(axis='both', which = 'major', labelsize= 10)
            #axs[0].legend(frameon = False, loc = 'upper right', fontsize = 10)
            axs[i].set_xlabel('R [Mpc]', fontsize = 10)
            axs[i].set_title(label_z, fontsize = 10)
            axs[0].set_ylabel(r'$\Delta\Sigma\ [M_\odot/$Mpc$^2]$', fontsize=14)
        #except: a=1
        
plt.legend(loc='upper center', bbox_to_anchor=(-2.5, 1.4),
          ncol=4, fancybox=True, shadow=True)

for ax in fig.get_axes():
    ax.label_outer()
#plt.savefig('../fig/stacked_redmapper_profiles.png', bbox_inches='tight', dpi=100)

# %% [markdown]
# ## Comparison calibrated to constantints data

# %%
import matplotlib.cm as cm
import matplotlib.colors as mcolors

# Color map to ensure consistent color across both plots
cmap = plt.get_cmap('tab10')  # Or use the same cmap as your SACC plots

z_bin_index = 2  # Third z-bin
z_bin = Z_bin[z_bin_index]
zbin = 'bin_z_2'
# Begin loop over richness bins
for rich_bin_index in range(4):
    rich_bin = f'bin_rich_{rich_bin_index}'
    color = cmap(rich_bin_index)  # Get consistent color per bin

    data_true = []
    data_true_error = []

    radius_vals = []

    for i in range(15):
        radius_key = f'radius_{i}'
        trac = ('cosmodc2-20deg2-CL', rich_bin, zbin, radius_key)
        print(trac)
        radius = t1.tracers[radius_key].center
        radius_vals.append(radius)
        print(t1.get_data_points(sacc.data_types.standard_types.cluster_delta_sigma, trac))
        data_true.append(t1.get_data_points(sacc.data_types.standard_types.cluster_delta_sigma, trac)[0].value)
        false_index = t1.indices(sacc.data_types.standard_types.cluster_delta_sigma, trac)
        data_true_error.append(np.sqrt(t1.covariance.covmat[false_index][:, false_index][0, 0]))

    # Plot SACC profile
    plt.errorbar(
        radius_vals, data_true, yerr=data_true_error,
        label=f'Cluster Pipeline: Rich bin {rich_bin}', marker='x', color=color, linestyle='-'
    )

    # --- Overlay original profile (dashed line) from Z_bin[2] ---
    m_bin = Obs_bin[rich_bin_index]
    mask_z = (profiles['z_mean'] > z_bin[0]) & (profiles['z_mean'] < z_bin[1])
    mask_m = (profiles['obs_mean'] > m_bin[0]) & (profiles['obs_mean'] < m_bin[1])
    index_cut = np.where(mask_z & mask_m)[0]

    if len(index_cut) > 0:
        f_cut = profiles[index_cut]
        cov = np.array(covariances['cov_t'][index_cut])
        err = cov.T.diagonal()**0.5
        plt.errorbar(
            f_cut['radius'][0], f_cut['gt'][0], err[0],
            label=f'Constantin : bin_rich_{rich_bin_index}', fmt='--', color=color,
            elinewidth=1, linewidth=1, markersize=3, marker='o', alpha=0.7
        )
plt.xlabel('Distance (Mpc)')
plt.ylabel(r'$\Delta \Sigma$')
plt.title(f'440deg² Cluster Profiles — Z bin {z_bin_index + 1}')
plt.xscale('log')
plt.yscale('log')
plt.xlim(0.4, 10)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_0')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_0'), value=48661110227266.11, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_1')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_1'), value=52185036944486.7, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_2')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_2'), value=48262287699473.15, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_3')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_3'), value=37320330179516.4, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_4')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_4'), value=26028842078322.176, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_5')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_5'), value=22184017975733.227, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_6')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_6'), value=18557475416981.93, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_7')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_7'), value=12707824439310.48, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_8')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_8'), value=9811482204720.516, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_9')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_9'), value=6483664179433.486, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_10')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_10'), value=4520260241317.037, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_11')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_11'), value=3579659100812.5664, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_12')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_12'), value=2753885907458.4824, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_13')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_13'), value=2244871589065.0605, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_14')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_0', 'bin_z_2', 'radius_14'), value=2142279729538.3662, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_0')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_0'), value=66740251018344.41, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_1')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_1'), value=72340841482621.81, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_2')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_2'), value=69548606899575.875, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_3')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_3'), value=56179268651014.26, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_4')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_4'), value=41494023660643.79, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_5')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_5'), value=36722764678773.11, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_6')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_6'), value=30039240365825.664, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_7')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_7'), value=20950647232882.598, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_8')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_8'), value=16089165056992.121, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_9')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_9'), value=11539250235525.457, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_10')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_10'), value=8313975438054.754, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_11')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_11'), value=5746956090079.114, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_12')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_12'), value=3395536598104.0366, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_13')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_13'), value=2614376871434.3257, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_14')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_1', 'bin_z_2', 'radius_14'), value=1755134440622.1072, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_0')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_0'), value=91316560496640.55, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_1')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_1'), value=104891802458248.69, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_2')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_2'), value=98879791124674.1, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_3')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_3'), value=80435974380877.0, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_4')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_4'), value=60697273990181.32, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_5')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_5'), value=50332185325120.03, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_6')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_6'), value=43559504730097.59, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_7')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_7'), value=31039039900195.42, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_8')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_8'), value=25810605117515.25, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_9')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_9'), value=16303847943687.156, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_10')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_10'), value=11731728050322.645, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_11')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_11'), value=10266490572541.094, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_12')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_12'), value=7288562629709.808, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_13')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_13'), value=8337872305278.617, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_14')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_2', 'bin_z_2', 'radius_14'), value=5648132428695.1455, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_0')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_0'), value=108116368825570.78, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_1')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_1'), value=113688006711632.73, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_2')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_2'), value=99151958975840.11, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_3')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_3'), value=78413119570074.95, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_4')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_4'), value=53076735873619.39, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_5')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_5'), value=47390001879116.26, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_6')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_6'), value=40613640815166.695, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_7')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_7'), value=29567073201308.727, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_8')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_8'), value=22544260006230.734, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_9')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_9'), value=13393450743462.957, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_10')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_10'), value=9776847696832.252, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_11')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_11'), value=10132831882639.182, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_12')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_12'), value=11585810452627.553, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_13')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_13'), value=6227960936448.5625, )]
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# [DataPoint(data_type='cluster_delta_sigma', tracers=('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14'), value=2284458545254.6997, )]

# %%
lsst_frace_output = '/sps/lsst/groups/clusters/cl_pipeline_project/TXPipe_data/cosmodc2/outputs-lsst-france/'
new_output = '/sps/lsst/groups/clusters/cl_pipeline_project/TXPipe_data/cosmodc2/outputs-full-2026/'

# %%
radius_vals = []
radius_test = []
for i in range(15):
    radius_key = f'radius_{i}'
    print(trac)
    radius = ((t1.tracers[radius_key].upper + t1.tracers[radius_key].lower) / 2)
    radius_vals.append(radius)
    radius = (t1.tracers[radius_key].center)
    radius_test.append(radius)
print(radius_vals, f"\n", radius_test)
# Out:
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# ('cosmodc2-20deg2-CL', 'bin_rich_3', 'bin_z_2', 'radius_14')
# [np.float64(0.5414786002949579), np.float64(0.6313176980145894), np.float64(0.7360623958349097), np.float64(0.8581857474708512), np.float64(1.0005711218635436), np.float64(1.166580280385366), np.float64(1.360132749033704), np.float64(1.5857983596147096), np.float64(1.8489051448421434), np.float64(2.1556651347869376), np.float64(2.5133210247693536), np.float64(2.9303171775666423), np.float64(3.4164989973495867), np.float64(3.983345382626338), np.float64(4.644239746477235)]
#  [np.float64(0.5572594390625522), np.float64(0.6800364734917794), np.float64(0.8307728756540614), np.float64(1.014633817831334), np.float64(1.238466768049785), np.float64(1.5122109315267438), np.float64(1.846485541628821), np.float64(2.2547756149753497), np.float64(2.7528669882823658), np.float64(3.361445830869178), np.float64(4.10442298604483), np.float64(5.011473048505655), np.float64(6.118889909615353), np.float64(7.471226709680845), np.float64(9.123408642881603)]
